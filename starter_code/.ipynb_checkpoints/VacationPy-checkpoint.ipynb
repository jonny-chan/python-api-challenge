# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import pprint as pp

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weatherdf = pd.read_csv("weatherdata.csv")

# %%
weatherdf.head(15)
# Out:
#     city_id               City  Cloudiness Country        Date  Humidity  \
# 0         0             faanui          21      PF  1570153552        80
# 1         1            ushuaia          40      AR  1570153588        98
# 2         2          mahebourg          16      MU  1570153633        65
# 3         3               chuy         100      UY  1570153622        87
# 4         4          oriximina          63      BR  1570153765        68
# 5         5            mataura         100      NZ  1570153540        58
# 6         6         butaritari         100      KI  1570153692        76
# 7         7             padang          94      ID  1570153555        83
# 8         8     port elizabeth          90      US  1570153768        93
# 9         9  ribnitz-damgarten          75      DE  1570153768        93
# 10       10         bredasdorp          94      ZA  1570153656        67
# 11       11          busselton          75      AU  1570153540        63
# 12       12              kapaa          75      US  1570153770        70
# 13       13         san andres           0      PH  1570153771        55
# 14       14            el alto          75      BO  1570153654        75
#
#       Lat     Lng  Max Temp  Wind Speed
# 0  -16.48 -151.75   298.836        7.25
# 1  -54.81  -68.31   281.150        8.20
# 2  -20.41   57.70   295.370        0.45
# 3  -33.69  -53.46   286.906        7.90
# 4   -1.77  -55.87   300.156        2.04
# 5  -46.19  168.86   289.820        5.81
# 6    3.07  172.79   300.376        4.61
# 7   -0.92  100.36   298.706        4.44
# 8   39.31  -74.98   294.820        1.50
# 9   54.24   12.43   280.150        4.06
# 10 -34.53   20.04   287.150        5.10
# 11 -33.64  115.35   288.710       11.93
# 12  22.08 -159.32   304.150        9.30
# 13  13.32  122.68   304.656        1.40
# 14 -16.50  -68.19   279.150        5.70

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = weatherdf[["Lat", "Lng"]].astype(float)
humidity = weatherdf["Humidity"].astype(float)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
#embed_minimal_html('export.html', views=[fig])
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
mintemp = float(input("What min temp?"))
maxtemp = float(input("What max temp?"))

newweather = weatherdf.loc[(weatherdf["Max Temp"]<=maxtemp + 273)&(weatherdf["Max Temp"]>=mintemp + 273)]
# Out:
# What min temp?22
# What max temp?33

# %%
newweather.head()
# Out:
#    city_id        City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0      faanui          21      PF  1570153552        80 -16.48
# 2        2   mahebourg          16      MU  1570153633        65 -20.41
# 4        4   oriximina          63      BR  1570153765        68  -1.77
# 6        6  butaritari         100      KI  1570153692        76   3.07
# 7        7      padang          94      ID  1570153555        83  -0.92
#
#       Lng  Max Temp  Wind Speed
# 0 -151.75   298.836        7.25
# 2   57.70   295.370        0.45
# 4  -55.87   300.156        2.04
# 6  172.79   300.376        4.61
# 7  100.36   298.706        4.44

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = newweather[["City","Lat","Lng","Max Temp"]].copy()

hotel_df.head()
# Out:
#          City    Lat     Lng  Max Temp
# 0      faanui -16.48 -151.75   298.836
# 2   mahebourg -20.41   57.70   295.370
# 4   oriximina  -1.77  -55.87   300.156
# 6  butaritari   3.07  172.79   300.376
# 7      padang  -0.92  100.36   298.706

# %%
hotel_df = hotel_df.reset_index()

# %%
# Hard coded sample for transversal
target_coordinates = "43.6187102, -116.2146068"
target_search = "Hotel"
target_radius = 8000
target_type = "hotel"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()
pp.pprint(response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAADn9xEfHji6AwN8x2eoi0NjG9KPhwWdA_YYQSczgKUBcU59JkJ-7DXIyIJ8_Ymyd1jY2fqH7XZnZecASY_yaJ1QAbfNIoe-s_16FBBQo3RufusHWCougS49NAuCxw3SncPAuBcPW0Xy2k8Ecf5q82pZB2dOTODuzc63FlwTGkga742L3LITXdq4X8-qBvqGpB5wC4C-8AVDxcr2KcievtbxRS3XN08QBjrK7RPsRcKjAclbbQ05oGOTPj-ZdTFT5RcRizibyEOvKco7pOkAr5axf7rH1-v8qzYJjRM0JXcsV7pV26gVp5WrxTQz7MEpD1jx-XouCy7f1ukNwY8tfsxeZ-Xe1P4b2eUjI9etsZGet9sHfKsQiWkbR4-4IfsSXiuTUkOV05eGHCmxZGqasHYASELYzgo_4mCwLKqS6tJdXs5gaFIAHaAN3YrPdfriI0dVlGivN6Afm',
#  'results': [{'geometry': {'location': {'lat': 43.6139805, 'lng': -116.2037792},
#                            'viewport': {'northeast': {'lat': 43.61524747989272,
#                                                       'lng': -116.2022788701073},
#                                         'southwest': {'lat': 43.61254782010728,
#                                                       'lng': -116.2049785298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '694216287367036e509fa82359c1e4bb8db01ea5',
#               'name': 'The Grove Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 553,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116907876961523237058/photos">The '
#                                                 'Grove Hotel</a>'],
#                           'photo_reference': 'CmRaAAAAspQ1T5iQ_QvLMbIXu45uHKJDHfYP6gKVTB18zE98v9qkE4G1YeuGAREyS8xG5AeK4UtzSS8mgblFHeNj5XJ5eRmf0XVhGecUpD9HPqiYOGn_Iy6tvxLlWZESjAHiAWGAEhDPHmRCZ95x0sVdmGzyqn1uGhRANCEUYzkTx4nqoa11OK7HIrzS9g',
#                           'width': 983}],
#               'place_id': 'ChIJJ4IrIeX4rlQRqU4eEpEWDNE',
#               'plus_code': {'compound_code': 'JQ7W+HF Boise, Idaho',
#                             'global_code': '85M5JQ7W+HF'},
#               'rating': 4.4,
#               'reference': 'ChIJJ4IrIeX4rlQRqU4eEpEWDNE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1488,
#               'vicinity': '245 S Capitol Blvd, Boise'},
#              {'geometry': {'location': {'lat': 43.5893611, 'lng': -116.2752977},
#                            'viewport': {'northeast': {'lat': 43.59089012989272,
#                                                       'lng': -116.2736533701073},
#                                         'southwest': {'lat': 43.58819047010728,
#                                                       'lng': -116.2763530298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3b42fc26d9ac7eeff0816aa5ecf05ef38f601cd7',
#               'name': 'Hampton Inn & Suites Boise/Spectrum',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 303,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117596962094002175702/photos">Hampton '
#                                                 'Inn &amp; Suites '
#                                                 'Boise/Spectrum</a>'],
#                           'photo_reference': 'CmRaAAAA6Ir6GGOmB83Toe8inScJpB-9w1OQC4Q33YMHHnBukOQ5HcxO23RJHrU5bnwL1IM4BsHh1rDK_MpGsF1E1MS9DyR-VDvwF5PIYButrFDi-a_UbLv4cyhN7mEdCt_y6yHWEhC_R535aLj-I4eVuypGkPMKGhRn4GMrZbtqbxZ5xiOSXRBXFC91xw',
#                           'width': 425}],
#               'place_id': 'ChIJKTY2eFJWrlQRfIU3XPM9He0',
#               'plus_code': {'compound_code': 'HPQF+PV Boise, Idaho',
#                             'global_code': '85M5HPQF+PV'},
#               'rating': 4.5,
#               'reference': 'ChIJKTY2eFJWrlQRfIU3XPM9He0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 486,
#               'vicinity': '7499 W Overland Rd, Boise'},
#              {'geometry': {'location': {'lat': 43.5745764, 'lng': -116.2177838},
#                            'viewport': {'northeast': {'lat': 43.57602092989272,
#                                                       'lng': -116.2168417201073},
#                                         'southwest': {'lat': 43.57332127010728,
#                                                       'lng': -116.2195413798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'e5adc0954a023b7d7921933f4b993b04c1c33669',
#               'name': 'Holiday Inn Express & Suites Boise Airport',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1250,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118284111836540628155/photos">Holiday '
#                                                 'Inn Express &amp; Suites '
#                                                 'Boise Airport</a>'],
#                           'photo_reference': 'CmRaAAAAOXoIcshAvDLxpnLvJLEQ00uq09AgJPabz2v6ycA34R4J0zKdHkKxK0qrhDw0BXVyUZ-YvSJJJSQvw2v-NM9Orun798Y6S4oJ_zU3yq81AP7od_Fr7t4qypvLhzlIZ0gdEhBepawJNQ1jzi8AddYbrlrMGhTApkyv0EiV8zDsjCpMoqd_cX166Q',
#                           'width': 4000}],
#               'place_id': 'ChIJUcIVjOFXrlQRN_Th7Y7ThPc',
#               'plus_code': {'compound_code': 'HQFJ+RV Boise, Idaho',
#                             'global_code': '85M5HQFJ+RV'},
#               'rating': 4.4,
#               'reference': 'ChIJUcIVjOFXrlQRN_Th7Y7ThPc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 561,
#               'vicinity': '3050 S Shoshone St, Boise'},
#              {'geometry': {'location': {'lat': 43.6112429, 'lng': -116.2028298},
#                            'viewport': {'northeast': {'lat': 43.61280317989272,
#                                                       'lng': -116.2012729701073},
#                                         'southwest': {'lat': 43.61010352010728,
#                                                       'lng': -116.2039726298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '90fdcd81f76f841f7e9a076d3b328c6a4275f91e',
#               'name': 'Stay Alfred at The Fowler',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 5248,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117705657320887531809/photos">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAquM9M-l29_srmGyHXp3O0q9if5wxiAbgg2H1tQjRsHvoZsQEoxgq6yqr3ytpAbc853mbbZJ2Ux6VoB1WtNx2O-rIokvuXLRHAdv_E2YVDQng2xP9F7lehzt4no3_DMpjEhAKm5rvO8lMjNuNz2PTm9mxGhQInAeXN8jFH1P8hdLfgGyME8biqw',
#                           'width': 7557}],
#               'place_id': 'ChIJx1yfSrX5rlQRp7elUQNxFgs',
#               'plus_code': {'compound_code': 'JQ6W+FV Boise, Idaho',
#                             'global_code': '85M5JQ6W+FV'},
#               'rating': 4.2,
#               'reference': 'ChIJx1yfSrX5rlQRp7elUQNxFgs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 44,
#               'vicinity': '505 W Broad St, Boise'},
#              {'geometry': {'location': {'lat': 43.5785194, 'lng': -116.2145114},
#                            'viewport': {'northeast': {'lat': 43.57989432989272,
#                                                       'lng': -116.2130325701073},
#                                         'southwest': {'lat': 43.57719467010728,
#                                                       'lng': -116.2157322298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'c7bb65c5d62e5edce0afe0e31fad2b5e1263d67d',
#               'name': 'La Quinta Inn & Suites by Wyndham Boise Airport',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 270,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104269613874352533774/photos">La '
#                                                 'Quinta Inn &amp; Suites Boise '
#                                                 'Airport</a>'],
#                           'photo_reference': 'CmRaAAAALdxyvLHeMgPO2rxcvFYa_KABZkvu8ovKbCEOVncIK-i3q9EIzabdx7kYLSKwJ8QXCBVNun2yht0uc6c5FuDLGH0BXlph8XHCNOLcHO_0CTb6RtN--7VYovkbjzZ6WeOKEhA5YfyE3FACUAnEQR9cox6ZGhR10q0zxt7ZJyC1QgpS3fLFM-fGDQ',
#                           'width': 480}],
#               'place_id': 'ChIJrTpItQv4rlQROtlW7z_SFzM',
#               'plus_code': {'compound_code': 'HQHP+C5 Boise, Idaho',
#                             'global_code': '85M5HQHP+C5'},
#               'rating': 4,
#               'reference': 'ChIJrTpItQv4rlQROtlW7z_SFzM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 653,
#               'vicinity': '2613 S Vista Ave, Boise'},
#              {'geometry': {'location': {'lat': 43.591733, 'lng': -116.27954},
#                            'viewport': {'northeast': {'lat': 43.59304192989272,
#                                                       'lng': -116.2784366201073},
#                                         'southwest': {'lat': 43.59034227010728,
#                                                       'lng': -116.2811362798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '71bdc16d4b0f8b5e9374b0e2d48202a0d2395340',
#               'name': 'Oxford Suites Boise',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100362697073353133852/photos">Oxford '
#                                                 'Suites Boise</a>'],
#                           'photo_reference': 'CmRaAAAAmtBh9RMCaF5ktwd-kaK8xyTzYl88uwguI2l_DOSI7-ER-agsr1xrlZqZs_QI5G60HbwQRE3SgI2DUxU6GVyy6xabVNOOnrN4zvqsMdQTkwe1dBXSTYA81gXBwrLKJniOEhCbP0DQJVuFK-ZfWnnywxt_GhTjb6VbqIfxcLuNOU_xaIyOwF0gtA',
#                           'width': 1080}],
#               'place_id': 'ChIJHSmqvlFWrlQRhg2utbwLw_o',
#               'plus_code': {'compound_code': 'HPRC+M5 Boise, Idaho',
#                             'global_code': '85M5HPRC+M5'},
#               'rating': 4.6,
#               'reference': 'ChIJHSmqvlFWrlQRhg2utbwLw_o',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 906,
#               'vicinity': '1426 S Entertainment Ave, Boise'},
#              {'geometry': {'location': {'lat': 43.5946353, 'lng': -116.1769814},
#                            'viewport': {'northeast': {'lat': 43.59584047989272,
#                                                       'lng': -116.1759430201073},
#                                         'southwest': {'lat': 43.59314082010728,
#                                                       'lng': -116.1786426798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'c2a5610a5420d0328a98f6798266ad00a27ac1d7',
#               'name': 'SpringHill Suites by Marriott Boise ParkCenter',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 423,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111182579042463555119/photos">SpringHill '
#                                                 'Suites Boise ParkCenter</a>'],
#                           'photo_reference': 'CmRaAAAA0Uk58sSIAa7gbf_9vqVPfL4Rw8RPZVFN7sBqERtnyagkM1Yez55CVScuUt3ew5Qj5Eib8CMiL4pvOUruakxAfSG3fBCB-XtRpYr9Oq3SbhqgHa3omRbs5iks4lbEWKlKEhBcvvKDijn2YMU6pDMo6YVjGhSxm_cBYuTMJiXvo0qx5lncQGbPcQ',
#                           'width': 610}],
#               'place_id': 'ChIJ9TlLoUv4rlQRNcJlnXTASUY',
#               'plus_code': {'compound_code': 'HRVF+V6 Boise, Idaho',
#                             'global_code': '85M5HRVF+V6'},
#               'rating': 4.5,
#               'reference': 'ChIJ9TlLoUv4rlQRNcJlnXTASUY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 634,
#               'vicinity': '424 E Parkcenter Blvd, Boise'},
#              {'geometry': {'location': {'lat': 43.618738, 'lng': -116.2046077},
#                            'viewport': {'northeast': {'lat': 43.62016822989273,
#                                                       'lng': -116.2036105201073},
#                                         'southwest': {'lat': 43.61746857010728,
#                                                       'lng': -116.2063101798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'ee6b212ed28360608d6a3bb9160c73c8e7268ec7',
#               'name': 'Hyatt Place Boise Downtown',
#               'photos': [{'height': 1836,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116874069144037677909/photos">Ed '
#                                                 'Ditlefsen</a>'],
#                           'photo_reference': 'CmRaAAAAxCp2P8Hn5Fe90PmUOhZhP-zoWIxSzXJPz2276iFRnu18JEBOsn_LoV9gtFBeGo3btHwLpqdSHEsnEy3iM0G_t3PkLuVYAJ9C9rFpkeS0Z6YFRiKOIV2Z0fFc-np94q9iEhBrxfZrO0OG1uti2kEQn22bGhQuAb-hX81-VgUIZm90DRpXEwIRQA',
#                           'width': 3264}],
#               'place_id': 'ChIJsRclsub4rlQRoYq4-UEhDxw',
#               'plus_code': {'compound_code': 'JQ9W+F5 Boise, Idaho',
#                             'global_code': '85M5JQ9W+F5'},
#               'rating': 4.6,
#               'reference': 'ChIJsRclsub4rlQRoYq4-UEhDxw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 526,
#               'vicinity': '1024 W Bannock St, Boise'},
#              {'geometry': {'location': {'lat': 43.5869896, 'lng': -116.2773572},
#                            'viewport': {'northeast': {'lat': 43.58832392989272,
#                                                       'lng': -116.2759454},
#                                         'southwest': {'lat': 43.58562427010727,
#                                                       'lng': -116.278717}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '41d4faa96b5e2c4d3aa656f4bad3af72aa9cee91',
#               'name': 'Hilton Garden Inn Boise Spectrum',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4478,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114089848929070741629/photos">Hilton '
#                                                 'Garden Inn Boise '
#                                                 'Spectrum</a>'],
#                           'photo_reference': 'CmRaAAAA0eM9wGWusLF5BYgniL1V6I7F7bGNMPhdJiKhkfL8TzCs6OhNMeK1PED9Hww3VoKX6yBKMUAWF0H5g5kX2irwbxcyj-VM_tbuhR_4LeJtp7Zmd7jzwhwxqPWD2I2huCZUEhBRPw2vJGsVB1PmAw_udK3RGhRFZWM8R4VQMQMZNzOW9L5MQt4ZAw',
#                           'width': 6709}],
#               'place_id': 'ChIJe8o3HFNWrlQRcJFz5UGo0Ic',
#               'plus_code': {'compound_code': 'HPPF+Q3 Boise, Idaho',
#                             'global_code': '85M5HPPF+Q3'},
#               'rating': 4.4,
#               'reference': 'ChIJe8o3HFNWrlQRcJFz5UGo0Ic',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 576,
#               'vicinity': '7699 W Spectrum St, Boise'},
#              {'geometry': {'location': {'lat': 43.6182841, 'lng': -116.2104661},
#                            'viewport': {'northeast': {'lat': 43.61972197989272,
#                                                       'lng': -116.2094443201073},
#                                         'southwest': {'lat': 43.61702232010728,
#                                                       'lng': -116.2121439798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'b76b556c1981e60826e9b1591d3997c34bf92289',
#               'name': 'Modern Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 751,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100408259027880832637/photos">The '
#                                                 'Modern Hotel and Bar</a>'],
#                           'photo_reference': 'CmRaAAAAGTFsbtihcQlB-jYxtIcyC2A8bMUdP1sBNPyW0PLp8otKziALJc4XzY4qgLIE6ixNnbRP-ESxB_g8VmgHbHrR95ihjy4gpFuZZhHNxsgbVkYEYiA1YFP3mjV4rNhy_XMXEhAB5nHHRWufjPCWtqH8ohPPGhQKQbJ9ncUBsAVdFKrH7keVeHlq4Q',
#                           'width': 1334}],
#               'place_id': 'ChIJ_fZEO-b4rlQRESiN6JvXLD8',
#               'plus_code': {'compound_code': 'JQ9Q+8R Boise, Idaho',
#                             'global_code': '85M5JQ9Q+8R'},
#               'rating': 4.6,
#               'reference': 'ChIJ_fZEO-b4rlQRESiN6JvXLD8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 561,
#               'vicinity': '1314 W Grove St, Boise'},
#              {'geometry': {'location': {'lat': 43.6123321, 'lng': -116.2055217},
#                            'viewport': {'northeast': {'lat': 43.61362782989273,
#                                                       'lng': -116.2040000701073},
#                                         'southwest': {'lat': 43.61092817010728,
#                                                       'lng': -116.2066997298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '828502c07366f8629e6e133c0415808b2e20ab5c',
#               'name': 'Hampton Inn & Suites Boise-Downtown',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3198,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114551667716962215520/photos">Hampton '
#                                                 'Inn &amp; Suites '
#                                                 'Boise-Downtown</a>'],
#                           'photo_reference': 'CmRaAAAABkYPO2ZixkrCNpbClsyJfIgejAStbe6W1nh6Q7U4YkS3bCRuHOfsco_qy6NKXypP85oYvG1Yc51GzO_CFfMXRxBoZ3fm6LNCXp70Euo04OB_1Pbenx2MBE-ZPMen1TN6EhACQfhpSVysbUNTXMRwDprxGhRX-fal2kpdhq9upM2YTOMuGlHlUQ',
#                           'width': 4477}],
#               'place_id': 'ChIJkf0tnvr4rlQRjL-FWTWCnUg',
#               'plus_code': {'compound_code': 'JQ6V+WQ Boise, Idaho',
#                             'global_code': '85M5JQ6V+WQ'},
#               'rating': 4.5,
#               'reference': 'ChIJkf0tnvr4rlQRjL-FWTWCnUg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 717,
#               'vicinity': '495 S Capitol Blvd, Boise'},
#              {'geometry': {'location': {'lat': 43.568697, 'lng': -116.214461},
#                            'viewport': {'northeast': {'lat': 43.57004102989271,
#                                                       'lng': -116.2129262201072},
#                                         'southwest': {'lat': 43.56734137010727,
#                                                       'lng': -116.2156258798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '794e1cdbaf71efd8ecd5feadaa619a919f502080',
#               'name': 'Best Western Vista Inn at the Airport',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2562,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114205240879513354023/photos">Best '
#                                                 'Western Vista Inn at the '
#                                                 'Airport</a>'],
#                           'photo_reference': 'CmRaAAAAFMfcbYcAZtPBEL_5MGr8WMwf_gWPnS_QCLrEthLue08lh3dPdMnQokH5E6rPBai8UPJ77WUkVb15SZH0r6FnGTs8P2BaH8bjtMGmv3UlfH8X_evTVBCNdbP_0fj7RKhhEhCY0gywiw7JD-Ol3QwJfuuQGhTYRRLgY_vq66a6qPyWJO1vvErF8Q',
#                           'width': 3839}],
#               'place_id': 'ChIJsb3eWvxXrlQRYB7IEt4JNxQ',
#               'plus_code': {'compound_code': 'HQ9P+F6 Boise, Idaho',
#                             'global_code': '85M5HQ9P+F6'},
#               'rating': 4.1,
#               'reference': 'ChIJsb3eWvxXrlQRYB7IEt4JNxQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 805,
#               'vicinity': '2645 W Airport Way, Boise'},
#              {'geometry': {'location': {'lat': 43.5733604, 'lng': -116.2254069},
#                            'viewport': {'northeast': {'lat': 43.57475067989272,
#                                                       'lng': -116.2240579701073},
#                                         'southwest': {'lat': 43.57205102010727,
#                                                       'lng': -116.2267576298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '0a026334e69bc1a6ef2776a91e8a1511c8d33787',
#               'name': 'Comfort Inn & Suites',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1365,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105239484842112551485/photos">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAsiSVs3QQlBfzz5BQUflsK6OGRxxiBUH3SnMcA_Nl4KXZmIiToLfoOdur-WDlaihR-YnuPZoyKqRDzN1G-mEMYP18mhRwK_kxxe4f4sheRQ6PXwrq9U8BxFkoMuyOyi4kEhD_OlJRs27xoVTZ7IRbp25xGhQ9U6iDxyrH6BXJuPLEl128zRRd1g',
#                           'width': 2048}],
#               'place_id': 'ChIJSdZ41v9XrlQRPPxIFo4h_5M',
#               'plus_code': {'compound_code': 'HQFF+8R Boise, Idaho',
#                             'global_code': '85M5HQFF+8R'},
#               'rating': 4.6,
#               'reference': 'ChIJSdZ41v9XrlQRPPxIFo4h_5M',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'bar', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 182,
#               'vicinity': '3625 W Elder St, Boise'},
#              {'geometry': {'location': {'lat': 43.6079234, 'lng': -116.1920443},
#                            'viewport': {'northeast': {'lat': 43.60928592989271,
#                                                       'lng': -116.1907202201073},
#                                         'southwest': {'lat': 43.60658627010727,
#                                                       'lng': -116.1934198798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '123ad5ab9bdaf9d12aad031c644a0bc915113878',
#               'name': 'Courtyard by Marriott Boise Downtown',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 423,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107514068945688437817/photos">Courtyard '
#                                                 'Boise Downtown</a>'],
#                           'photo_reference': 'CmRaAAAAFcS_wsSwcrpSmK7Csz9Gr7L5iBig04EFG2kkt_NsPrCn7RypVp71MuU6uX2pdj7GEtdT2jJpRXjsjQNaxBBBn_FRRcYw-3vJu8m1WU7Z-zASPIEbcniowNLsXWyue1zrEhBx3rCELzXeRbZeWQ81GaC0GhQfdlVM_9N4cPNrjG_ue7QGsCWdUA',
#                           'width': 610}],
#               'place_id': 'ChIJwwMgPf_4rlQRLnKzLdIkIP8',
#               'plus_code': {'compound_code': 'JR55+55 Boise, Idaho',
#                             'global_code': '85M5JR55+55'},
#               'rating': 4.4,
#               'reference': 'ChIJwwMgPf_4rlQRLnKzLdIkIP8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 389,
#               'vicinity': '222 Broadway Ave, Boise'},
#              {'geometry': {'location': {'lat': 43.62128910000001,
#                                         'lng': -116.2343917},
#                            'viewport': {'northeast': {'lat': 43.62383870000001,
#                                                       'lng': -116.22966445},
#                                         'southwest': {'lat': 43.61885110000001,
#                                                       'lng': -116.23869065}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '8a2c77e499f3c0c6bda3facdb6a200d36fac13f5',
#               'name': 'The Riverside Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 356,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100436143966565912359/photos">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA3geVfjZFMllGpEnsFZqW7Od1hFG4CZ_L6dCcKvLn8z5xfpdrjipzhL6ztPQsyHY1nEmza61j2kQI8H0j81soGJ1syNjrLrRWlqsPYeBJEU9K_Hiqpio6NO7jCWykPGx5EhB5Lfg9gzCfz658gn45Dk0YGhSfb8azsboGxhLL7kjA8UExoaE9Aw',
#                           'width': 533}],
#               'place_id': 'ChIJrWs2O7n4rlQRVzz4Wl1XLMs',
#               'plus_code': {'compound_code': 'JQC8+G6 Boise, Idaho',
#                             'global_code': '85M5JQC8+G6'},
#               'rating': 4.4,
#               'reference': 'ChIJrWs2O7n4rlQRVzz4Wl1XLMs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1661,
#               'vicinity': '2900 W Chinden Blvd, Boise'},
#              {'geometry': {'location': {'lat': 43.6104171, 'lng': -116.2813821},
#                            'viewport': {'northeast': {'lat': 43.61187102989272,
#                                                       'lng': -116.2799541701073},
#                                         'southwest': {'lat': 43.60917137010728,
#                                                       'lng': -116.2826538298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'eeba5308eb580b201a4cf5a018c3fa398bab16e4',
#               'name': 'La Quinta Inn & Suites by Wyndham Boise Towne Square',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 270,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101851325756239637827/photos">La '
#                                                 'Quinta Inn &amp; Suites Boise '
#                                                 'Towne Square</a>'],
#                           'photo_reference': 'CmRaAAAAoUg023PApHmVfvn0aEHoLt2JTUKGmGaL77j2XCjomxdbpfNNbRQ-UH5kI-sFtry5SH70UmahHFXpsCTd14i57T6wMWbp7QU7QRlutrR71sxdkAuldRWZeK9z5Q8rRcBXEhCTMyqnTAjqALvBa1VPl9okGhQxq9dRXwxslW4BwFvSFX5xrPompA',
#                           'width': 480}],
#               'place_id': 'ChIJoZutzmxWrlQRTT3zMLEZ26M',
#               'plus_code': {'compound_code': 'JP69+5C Boise, Idaho',
#                             'global_code': '85M5JP69+5C'},
#               'rating': 4.1,
#               'reference': 'ChIJoZutzmxWrlQRTT3zMLEZ26M',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 603,
#               'vicinity': '7965 W Emerald St, Boise'},
#              {'geometry': {'location': {'lat': 43.6164368, 'lng': -116.210439},
#                            'viewport': {'northeast': {'lat': 43.61795017989271,
#                                                       'lng': -116.2094166701073},
#                                         'southwest': {'lat': 43.61525052010727,
#                                                       'lng': -116.2121163298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '0979baf0db0cecd340a3712e0d97277170594315',
#               'name': 'Hilton Garden Inn Boise Downtown',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107688252312531925398/photos">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAIeJruHefUtVsElwYZtWuzfXWP1BtHW2CdTqeu2EHflMe1Zf097DpySjr8ZcA0FJCwCH8yB-FWg_mKFnMMuWdrKZkBQAt4QsrzzhYthTMk2u2ggeF_Tzj05IFPB0xmie6EhAUc-w6h4JU0lMyLx8zKLeGGhSGqgnRWXat20fFM8HYfED5Ng_vWg',
#                           'width': 4772}],
#               'place_id': 'ChIJAXRbTu_4rlQRn6YcHtVNh-I',
#               'plus_code': {'compound_code': 'JQ8Q+HR Boise, Idaho',
#                             'global_code': '85M5JQ8Q+HR'},
#               'rating': 4.5,
#               'reference': 'ChIJAXRbTu_4rlQRn6YcHtVNh-I',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 163,
#               'vicinity': '348 S 13th St, Boise'},
#              {'geometry': {'location': {'lat': 43.6042232, 'lng': -116.2137018},
#                            'viewport': {'northeast': {'lat': 43.60566847989273,
#                                                       'lng': -116.2123773201073},
#                                         'southwest': {'lat': 43.60296882010728,
#                                                       'lng': -116.2150769798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '5941c7b7ab3e16e969eb9c8429c87ceb30361b71',
#               'name': 'TownePlace Suites by Marriott Boise Downtown/University',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106830035009248980494/photos">TownePlace '
#                                                 'Suites Boise Downtown</a>'],
#                           'photo_reference': 'CmRaAAAA3_hW1ea4NHdlJOtQTdsT9qKo5ILPJuid8FIbO-ZCEtOVteQv3sevDWFLV-4PJiB8Oq7XvooZXPvwo-D5YIp7eLUTpGLFMj3k3OMOZe5NYjfvJWe7GUXT2XKrih_5Z1fKEhAzaCn5zzKMZWiYpcyfnRrTGhTNKqi4Qk6Vi4a5AVm6X0OLpmC8ew',
#                           'width': 3000}],
#               'place_id': 'ChIJK8VPLIv4rlQRBRtqqcDjKG4',
#               'plus_code': {'compound_code': 'JQ3P+MG Boise, Idaho',
#                             'global_code': '85M5JQ3P+MG'},
#               'rating': 4.4,
#               'reference': 'ChIJK8VPLIv4rlQRBRtqqcDjKG4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 308,
#               'vicinity': '1455 S Capitol Blvd, Boise'},
#              {'geometry': {'location': {'lat': 43.5690111, 'lng': -116.2093853},
#                            'viewport': {'northeast': {'lat': 43.57059737989272,
#                                                       'lng': -116.2081955701073},
#                                         'southwest': {'lat': 43.56789772010728,
#                                                       'lng': -116.2108952298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4e09f85daaf448e34fab11c222ffe5d34d0609f1',
#               'name': 'Inn America - Boise',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 425,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107115398108460767243/photos">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAApkFw8pc6mRfUtZnNoWizfTa0zhYJ5Okkrz6e1laV0VH0rLHV7fAZl0dCPf5EcHQPFEx6MthMbO9MJiepsFcBAUEVi0W_u_YXig_neE7jQlFlKGmtGqp-ZN8OJ_cL9H1REhAfZkpRNWgl_MicMT2t_-U8GhSRtHCCyDM6z6DJS3YNNfo7BlyzWg',
#                           'width': 640}],
#               'place_id': 'ChIJ-SsC-P1XrlQRv0kt0hrodRc',
#               'plus_code': {'compound_code': 'HQ9R+J6 Boise, Idaho',
#                             'global_code': '85M5HQ9R+J6'},
#               'rating': 4.2,
#               'reference': 'ChIJ-SsC-P1XrlQRv0kt0hrodRc',
#               'scope': 'GOOGLE',
#               'types': ['travel_agency',
#                         'lodging',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 304,
#               'vicinity': '2275 W Airport Way, Boise'},
#              {'geometry': {'location': {'lat': 43.6131807, 'lng': -116.2854112},
#                            'viewport': {'northeast': {'lat': 43.61447107989272,
#                                                       'lng': -116.2840747701073},
#                                         'southwest': {'lat': 43.61177142010727,
#                                                       'lng': -116.2867744298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '45f187df95b7f6917a96c3346b0e12ce678ee0d4',
#               'name': 'Hyatt Place Boise/Towne Square',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1916,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116870466062571260322/photos">Hyatt '
#                                                 'Place Boise/Towne Square</a>'],
#                           'photo_reference': 'CmRaAAAABirPKGBuZOMH4e-S2sirF8bnMg22WmrfTIMesSbdri1czhP849dHowraA6fJih8-YXzwVdK5U1IzcJ40PswGr-en40R_JHxYvWcIi9nfqgbaU9o9AAR0AD73-Q84eiPSEhAbWCYRlviCwnk8fNsYYEiOGhS8wjJr68z5Y_H2x00g3RhrdMCOdw',
#                           'width': 2879}],
#               'place_id': 'ChIJWyJVmXJWrlQRpXS3inAbxYo',
#               'plus_code': {'compound_code': 'JP77+7R Boise, Idaho',
#                             'global_code': '85M5JP77+7R'},
#               'rating': 4.3,
#               'reference': 'ChIJWyJVmXJWrlQRpXS3inAbxYo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 663,
#               'vicinity': '925 N Milwaukee St, Boise'}],
#  'status': 'OK'}

# %%
name = response['results'][0]['name']
name
# Out:
# 'The Grove Hotel'

# %%
hotelLatitude = response['results'][0]['geometry']['location']['lat']
hotelLatitude
# Out:
# 43.6139805

# %%
hotelLongitude = response['results'][0]['geometry']['location']['lng']
hotelLongitude
# Out:
# -116.2037792

# %%
#Loop through each row to pull hotel data from Google
total = len(hotel_df)
rowCount = 1

hotel_df['Hotel'] = ""
hotel_df['Hotel Latitude'] = ""
hotel_df['Hotel Longitude'] = ""

for index, row in hotel_df.iterrows():
    print(f"Processing row #{index} of {total}")
    
    lat = str(row['Lat'])
    lon = str(row['Lng'])
    
    target_coordinates = lat + ", " + lon
    target_search = "Hotel"
    target_radius = 5000
    target_type = "hotel"
    
    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Request the hotel data using the parameters
    response = requests.get(base_url, params=params).json()
    
    # Traverse and store the hotel details
    row['Hotel'] = response['results'][0]['name']
    row['Hotel Latitude'] = response['results'][0]['geometry']['location']['lat']
    row['Hotel Longitude'] = response['results'][0]['geometry']['location']['lng']
          
    rowCount += 1
# Out:
# Processing row #0 of 183
# Processing row #2 of 183
# Processing row #4 of 183
# Processing row #6 of 183
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-d7e6b988b6e3> in <module>
#      33
#      34     # Traverse and store the hotel details
# ---> 35     row['Hotel'] = response['results'][0]['name']
#      36     row['Hotel Latitude'] = response['results'][0]['geometry']['location']['lat']
#      37     row['Hotel Longitude'] = response['results'][0]['geometry']['location']['lng']
#
# IndexError: list index out of range

# %%
hotel_df.head()
# Out:
#          City    Lat     Lng  Max Temp Hotel Hotel Latitude Hotel Longitude
# 0      faanui -16.48 -151.75   298.836
# 2   mahebourg -20.41   57.70   295.370
# 4   oriximina  -1.77  -55.87   300.156
# 6  butaritari   3.07  172.79   300.376
# 7      padang  -0.92  100.36   298.706

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display Map
